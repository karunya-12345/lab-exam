# %% [markdown]
# <a href="https://colab.research.google.com/github/bhmanashwi/lab_exam/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file_path="/content/drive/my_Drive/ODD.xlsx"
df=pd.read_excel("/ODD.xlsx")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.isna()
# Out:
#     Employee_Name  Employee_ID  Job_Role  Phone_Number  Email_ID  \
# 0           False        False     False         False     False
# 1           False        False     False         False     False
# 2           False        False     False         False     False
# 3           False        False     False         False     False
# 4           False        False     False         False     False
# ..            ...          ...       ...           ...       ...
# 95          False        False      True         False     False
# 96          False        False     False         False     False
# 97           True        False     False         False     False
# 98          False        False     False         False     False
# 99          False        False     False         False     False
#
#     Total_Work_Hour_per_Month  Salary_per_Month
# 0                       False              True
# 1                       False             False
# ...

# %%
nc=df.columns[df.isnull().any()].tolist()
print(nc)
# Out:
# ['Employee_Name', 'Job_Role', 'Phone_Number', 'Email_ID', 'Total_Work_Hour_per_Month', 'Salary_per_Month']

# %%
print(df.dtypes)
# Out:
# Employee_Name                 object
# Employee_ID                    int64
# Job_Role                      object
# Phone_Number                 float64
# Email_ID                      object
# Total_Work_Hour_per_Month    float64
# Salary_per_Month             float64
# dtype: object

# %%
df["Phone_Number"]= pd.to_numeric(df["Phone_Number"], errors='coerce')
print(df.dtypes)
# Out:
# Employee_Name                 object
# Employee_ID                    int64
# Job_Role                      object
# Phone_Number                 float64
# Email_ID                      object
# Total_Work_Hour_per_Month    float64
# Salary_per_Month             float64
# dtype: object

# %%
# Compute Hourly Wage
df["Hourly_Wage"] = df["Salary_per_Month"] / df["Total_Work_Hour_per_Month"]

# Display a sample of the results
df[["Salary_per_Month", "Total_Work_Hour_per_Month", "Hourly_Wage"]].head()  # Viewing computed values
# Out:
#    Salary_per_Month  Total_Work_Hour_per_Month  Hourly_Wage
# 0               NaN                        0.0          NaN
# 1           11200.0                      160.0         70.0
# 2           -5000.0                        0.0         -inf
# 3            8000.0                      160.0         50.0
# 4               NaN                        0.0          NaN
